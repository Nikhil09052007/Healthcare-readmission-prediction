# %% [markdown]
# 01.Importing all the required libraires at once.

# %%
# These libraries are sufficient for our Data analysis section.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Importing the dataset.

# %%
df = pd.read_csv(r'C:\Users\Nikhil Pandey\OneDrive\Desktop\PROGRAM\Projects\Heart_desease\data\raw\diabetes_raw.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      99493 non-null   object
#  1   gender                    101766 non-null  object
#  2   age                       101766 non-null  object
#  3   weight                    3197 non-null    object
#  4   admission_type_id         101766 non-null  int64
#  5   discharge_disposition_id  101766 non-null  int64
#  6   admission_source_id       101766 non-null  int64
#  7   time_in_hospital          101766 non-null  int64
#  8   payer_code                61510 non-null   object
#  9   medical_specialty         51817 non-null   object
#  10  num_lab_procedures        101766 non-null  int64
#  11  num_procedures            101766 non-null  int64
#  12  num_medications           101766 non-null  int64
#  13  number_outpatient         101766 non-null  int64
#  14  number_emergency          101766 non-null  int64
#  15  number_inpatient          101766 non-null  int64
#  16  diag_1                    101745 non-null  object
#  17  diag_2                    101408 non-null  object
#  18  diag_3                    100343 non-null  object
#  19  number_diagnoses          101766 non-null  int64
#  20  max_glu_serum             5346 non-null    object
#  21  A1Cresult                 17018 non-null   object
#  22  metformin                 101766 non-null  object
#  23  repaglinide               101766 non-null  object
#  24  nateglinide               101766 non-null  object
#  25  chlorpropamide            101766 non-null  object
#  26  glimepiride               101766 non-null  object
#  27  acetohexamide             101766 non-null  object
#  28  glipizide                 101766 non-null  object
#  29  glyburide                 101766 non-null  object
#  30  tolbutamide               101766 non-null  object
#  31  pioglitazone              101766 non-null  object
#  32  rosiglitazone             101766 non-null  object
#  33  acarbose                  101766 non-null  object
#  34  miglitol                  101766 non-null  object
#  35  troglitazone              101766 non-null  object
#  36  tolazamide                101766 non-null  object
#  37  examide                   101766 non-null  object
#  38  citoglipton               101766 non-null  object
#  39  insulin                   101766 non-null  object
#  40  glyburide-metformin       101766 non-null  object
#  41  glipizide-metformin       101766 non-null  object
#  42  glimepiride-pioglitazone  101766 non-null  object
#  43  metformin-rosiglitazone   101766 non-null  object
#  44  metformin-pioglitazone    101766 non-null  object
#  45  change                    101766 non-null  object
#  46  diabetesMed               101766 non-null  object
#  47  readmitted                101766 non-null  object
# dtypes: int64(11), object(37)
# memory usage: 37.3+ MB

# %%
print(df.columns.tolist()) # Extracting titlecims
# Out:
# ['race', 'gender', 'age', 'weight', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'payer_code', 'medical_specialty', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted']

# %% [markdown]
# # EDA and Data Analysis:

# %%
# I'm gonna use ydataprofiling as a help:
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # I'm gonna use ydataprofiling as a help:
# ----> 2 from ydata_profiling import ProfileReport
#       3 prof=ProfileReport(df)
#       4 prof.to_file(output_file='output.html')
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\ydata_profiling\profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
for col in df.columns:
    print(f"\n{'='*55}")
    print(f"COLUMN : {col}")
    print(f"dtype  : {df[col].dtype}")
    print(f"missing: {df[col].isnull().sum()} | '?' values: {(df[col] == '?').sum()}")
    print(f"unique : {df[col].nunique()}")
    print(f"values : {df[col].value_counts().head(5).to_dict()}")
    print(f"{'='*55}")
    print(f"")
# Out:
# =======================================================
# COLUMN : race
# dtype  : object
# missing: 2273 | '?' values: 0
# unique : 5
# values : {'Caucasian': 76099, 'AfricanAmerican': 19210, 'Hispanic': 2037, 'Other': 1506, 'Asian': 641}
# =======================================================
#
#
# =======================================================
# COLUMN : gender
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 3
# values : {'Female': 54708, 'Male': 47055, 'Unknown/Invalid': 3}
# =======================================================
#
#
# =======================================================
# COLUMN : age
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 10
# values : {'[70-80)': 26068, '[60-70)': 22483, '[50-60)': 17256, '[80-90)': 17197, '[40-50)': 9685}
# =======================================================
#
#
# =======================================================
# COLUMN : weight
# dtype  : object
# missing: 98569 | '?' values: 0
# unique : 9
# values : {'[75-100)': 1336, '[50-75)': 897, '[100-125)': 625, '[125-150)': 145, '[25-50)': 97}
# =======================================================
#
#
# =======================================================
# COLUMN : admission_type_id
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 8
# values : {1: 53990, 3: 18869, 2: 18480, 6: 5291, 5: 4785}
# =======================================================
#
#
# =======================================================
# COLUMN : discharge_disposition_id
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 26
# values : {1: 60234, 3: 13954, 6: 12902, 18: 3691, 2: 2128}
# =======================================================
#
#
# =======================================================
# COLUMN : admission_source_id
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 17
# values : {7: 57494, 1: 29565, 17: 6781, 4: 3187, 6: 2264}
# =======================================================
#
#
# =======================================================
# COLUMN : time_in_hospital
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 14
# values : {3: 17756, 2: 17224, 1: 14208, 4: 13924, 5: 9966}
# =======================================================
#
#
# =======================================================
# COLUMN : payer_code
# dtype  : object
# missing: 40256 | '?' values: 0
# unique : 17
# values : {'MC': 32439, 'HM': 6274, 'SP': 5007, 'BC': 4655, 'MD': 3532}
# =======================================================
#
#
# =======================================================
# COLUMN : medical_specialty
# dtype  : object
# missing: 49949 | '?' values: 0
# unique : 72
# values : {'InternalMedicine': 14635, 'Emergency/Trauma': 7565, 'Family/GeneralPractice': 7440, 'Cardiology': 5352, 'Surgery-General': 3099}
# =======================================================
#
#
# =======================================================
# COLUMN : num_lab_procedures
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 118
# values : {1: 3208, 43: 2804, 44: 2496, 45: 2376, 38: 2213}
# =======================================================
#
#
# =======================================================
# COLUMN : num_procedures
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 7
# values : {0: 46652, 1: 20742, 2: 12717, 3: 9443, 6: 4954}
# =======================================================
#
#
# =======================================================
# COLUMN : num_medications
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 75
# values : {13: 6086, 12: 6004, 11: 5795, 15: 5792, 14: 5707}
# =======================================================
#
#
# =======================================================
# COLUMN : number_outpatient
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 39
# values : {0: 85027, 1: 8547, 2: 3594, 3: 2042, 4: 1099}
# =======================================================
#
#
# =======================================================
# COLUMN : number_emergency
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 33
# values : {0: 90383, 1: 7677, 2: 2042, 3: 725, 4: 374}
# =======================================================
#
#
# =======================================================
# COLUMN : number_inpatient
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 21
# values : {0: 67630, 1: 19521, 2: 7566, 3: 3411, 4: 1622}
# =======================================================
#
#
# =======================================================
# COLUMN : diag_1
# dtype  : object
# missing: 21 | '?' values: 0
# unique : 716
# values : {'428': 6862, '414': 6581, '786': 4016, '410': 3614, '486': 3508}
# =======================================================
#
#
# =======================================================
# COLUMN : diag_2
# dtype  : object
# missing: 358 | '?' values: 0
# unique : 748
# values : {'276': 6752, '428': 6662, '250': 6071, '427': 5036, '401': 3736}
# =======================================================
#
#
# =======================================================
# COLUMN : diag_3
# dtype  : object
# missing: 1423 | '?' values: 0
# unique : 789
# values : {'250': 11555, '401': 8289, '276': 5175, '428': 4577, '427': 3955}
# =======================================================
#
#
# =======================================================
# COLUMN : number_diagnoses
# dtype  : int64
# missing: 0 | '?' values: 0
# unique : 16
# values : {9: 49474, 5: 11393, 8: 10616, 7: 10393, 6: 10161}
# =======================================================
#
#
# =======================================================
# COLUMN : max_glu_serum
# dtype  : object
# missing: 96420 | '?' values: 0
# unique : 3
# values : {'Norm': 2597, '>200': 1485, '>300': 1264}
# =======================================================
#
#
# =======================================================
# COLUMN : A1Cresult
# dtype  : object
# missing: 84748 | '?' values: 0
# unique : 3
# values : {'>8': 8216, 'Norm': 4990, '>7': 3812}
# =======================================================
#
#
# =======================================================
# COLUMN : metformin
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 81778, 'Steady': 18346, 'Up': 1067, 'Down': 575}
# =======================================================
#
#
# =======================================================
# COLUMN : repaglinide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 100227, 'Steady': 1384, 'Up': 110, 'Down': 45}
# =======================================================
#
#
# =======================================================
# COLUMN : nateglinide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 101063, 'Steady': 668, 'Up': 24, 'Down': 11}
# =======================================================
#
#
# =======================================================
# COLUMN : chlorpropamide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 101680, 'Steady': 79, 'Up': 6, 'Down': 1}
# =======================================================
#
#
# =======================================================
# COLUMN : glimepiride
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 96575, 'Steady': 4670, 'Up': 327, 'Down': 194}
# =======================================================
#
#
# =======================================================
# COLUMN : acetohexamide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'No': 101765, 'Steady': 1}
# =======================================================
#
#
# =======================================================
# COLUMN : glipizide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 89080, 'Steady': 11356, 'Up': 770, 'Down': 560}
# =======================================================
#
#
# =======================================================
# COLUMN : glyburide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 91116, 'Steady': 9274, 'Up': 812, 'Down': 564}
# =======================================================
#
#
# =======================================================
# COLUMN : tolbutamide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'No': 101743, 'Steady': 23}
# =======================================================
#
#
# =======================================================
# COLUMN : pioglitazone
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 94438, 'Steady': 6976, 'Up': 234, 'Down': 118}
# =======================================================
#
#
# =======================================================
# COLUMN : rosiglitazone
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 95401, 'Steady': 6100, 'Up': 178, 'Down': 87}
# =======================================================
#
#
# =======================================================
# COLUMN : acarbose
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 101458, 'Steady': 295, 'Up': 10, 'Down': 3}
# =======================================================
#
#
# =======================================================
# COLUMN : miglitol
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 101728, 'Steady': 31, 'Down': 5, 'Up': 2}
# =======================================================
#
#
# =======================================================
# COLUMN : troglitazone
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'No': 101763, 'Steady': 3}
# =======================================================
#
#
# =======================================================
# COLUMN : tolazamide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 3
# values : {'No': 101727, 'Steady': 38, 'Up': 1}
# =======================================================
#
#
# =======================================================
# COLUMN : examide
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 1
# values : {'No': 101766}
# =======================================================
#
#
# =======================================================
# COLUMN : citoglipton
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 1
# values : {'No': 101766}
# =======================================================
#
#
# =======================================================
# COLUMN : insulin
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 47383, 'Steady': 30849, 'Down': 12218, 'Up': 11316}
# =======================================================
#
#
# =======================================================
# COLUMN : glyburide-metformin
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 4
# values : {'No': 101060, 'Steady': 692, 'Up': 8, 'Down': 6}
# =======================================================
#
#
# =======================================================
# COLUMN : glipizide-metformin
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'No': 101753, 'Steady': 13}
# =======================================================
#
#
# =======================================================
# COLUMN : glimepiride-pioglitazone
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'No': 101765, 'Steady': 1}
# =======================================================
#
#
# =======================================================
# COLUMN : metformin-rosiglitazone
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'No': 101764, 'Steady': 2}
# =======================================================
#
#
# =======================================================
# COLUMN : metformin-pioglitazone
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'No': 101765, 'Steady': 1}
# =======================================================
#
#
# =======================================================
# COLUMN : change
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'No': 54755, 'Ch': 47011}
# =======================================================
#
#
# =======================================================
# COLUMN : diabetesMed
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 2
# values : {'Yes': 78363, 'No': 23403}
# =======================================================
#
#
# =======================================================
# COLUMN : readmitted
# dtype  : object
# missing: 0 | '?' values: 0
# unique : 3
# values : {'NO': 54864, '>30': 35545, '<30': 11357}
# =======================================================

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      99493 non-null   object
#  1   gender                    101766 non-null  object
#  2   age                       101766 non-null  object
#  3   weight                    3197 non-null    object
#  4   admission_type_id         101766 non-null  int64
#  5   discharge_disposition_id  101766 non-null  int64
#  6   admission_source_id       101766 non-null  int64
#  7   time_in_hospital          101766 non-null  int64
#  8   payer_code                61510 non-null   object
#  9   medical_specialty         51817 non-null   object
#  10  num_lab_procedures        101766 non-null  int64
#  11  num_procedures            101766 non-null  int64
#  12  num_medications           101766 non-null  int64
#  13  number_outpatient         101766 non-null  int64
#  14  number_emergency          101766 non-null  int64
#  15  number_inpatient          101766 non-null  int64
#  16  diag_1                    101745 non-null  object
#  17  diag_2                    101408 non-null  object
#  18  diag_3                    100343 non-null  object
#  19  number_diagnoses          101766 non-null  int64
#  20  max_glu_serum             5346 non-null    object
#  21  A1Cresult                 17018 non-null   object
#  22  metformin                 101766 non-null  object
#  23  repaglinide               101766 non-null  object
#  24  nateglinide               101766 non-null  object
#  25  chlorpropamide            101766 non-null  object
#  26  glimepiride               101766 non-null  object
#  27  acetohexamide             101766 non-null  object
#  28  glipizide                 101766 non-null  object
#  29  glyburide                 101766 non-null  object
#  30  tolbutamide               101766 non-null  object
#  31  pioglitazone              101766 non-null  object
#  32  rosiglitazone             101766 non-null  object
#  33  acarbose                  101766 non-null  object
#  34  miglitol                  101766 non-null  object
#  35  troglitazone              101766 non-null  object
#  36  tolazamide                101766 non-null  object
#  37  examide                   101766 non-null  object
#  38  citoglipton               101766 non-null  object
#  39  insulin                   101766 non-null  object
#  40  glyburide-metformin       101766 non-null  object
#  41  glipizide-metformin       101766 non-null  object
#  42  glimepiride-pioglitazone  101766 non-null  object
#  43  metformin-rosiglitazone   101766 non-null  object
#  44  metformin-pioglitazone    101766 non-null  object
#  45  change                    101766 non-null  object
#  46  diabetesMed               101766 non-null  object
#  47  readmitted                101766 non-null  object
# dtypes: int64(11), object(37)
# memory usage: 37.3+ MB

# %% [markdown]
# # Exploratory Data Analysis:

# %% [markdown]
# Tere are some unnecessary columns in our dataset which are just random noise for the workflow. Let's get rid of them:
# * weight                    → ~97% missing, can't impute this
# * payer_code                → ~40% missing, low clinical value
# * medical_specialty         → 50%+ missing, too vague for prediction
#
# * These drug columns are 99%+ "No" — they add no signal to the model:
# examide
# citoglipton
# glimepiride-pioglitazone
# metformin-rosiglitazone
# metformin-pioglitazone
# acetohexamide
# tolbutamide
# tolazamide
# troglitazone

# %%
df.drop([
    'weight',
    'payer_code',
    'medical_specialty',
    'examide',
    'citoglipton',
    'glimepiride-pioglitazone',
    'metformin-rosiglitazone',
    'metformin-pioglitazone',
    'acetohexamide',
    'tolbutamide',
    'tolazamide',
    'troglitazone'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['race', 'gender', 'age', 'weight', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'payer_code', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
#        'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df_c = df.copy(usecols=)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.corr()
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11072         """  # noqa: E501
#   11073         data = self._get_numeric_data() if numeric_only else self
#   11074         cols = data.columns
#   11075         idx = cols.copy()
# > 11076         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11077
#   11078         if method == "pearson":
#   11079             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1998                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    1999         """
#    2000         if dtype is not None:
#    2001             dtype = np.dtype(dtype)
# -> 2002         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003         if result.dtype is not dtype:
#    2004             result = np.asarray(result, dtype=dtype)
#    2005
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Caucasian'

# %%
df.shape
# Out:
# (101766, 36)

# %% [markdown]
# # Univeriate anlysis:

# %%
df.columns
# Out:
# Index(['race', 'gender', 'age', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'glipizide', 'glyburide', 'pioglitazone',
#        'rosiglitazone', 'acarbose', 'miglitol', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin', 'change', 'diabetesMed',
#        'readmitted'],
#       dtype='object')

# %%
df['readmitted'].unique()
# Out:
# array(['NO', '>30', '<30'], dtype=object)

# %%
df['readmitted'].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['readmitted'].plot(kind='bar')
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File c:\Users\Nikhil Pandey\OneDrive\Desktop\Jarvis 1.0\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot
